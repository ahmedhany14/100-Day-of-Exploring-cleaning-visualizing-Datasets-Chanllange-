# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
pd.options.display.max_columns = None
netflix_bestMovies_By_Year = pd.read_csv(r'E:\data analysis projects\Netflix\Best Movie by Year Netflix.csv')
netflix_bestMovies = pd.read_csv(r'E:\data analysis projects\Netflix\Best Movies Netflix.csv')
netflix_bestShow_By_Year = pd.read_csv(r'E:\data analysis projects\Netflix\Best Show by Year Netflix.csv')
netflix_bestShows = pd.read_csv(r'E:\data analysis projects\Netflix\Best Shows Netflix.csv')
netflix_raw_credits = pd.read_csv(r'E:\data analysis projects\Netflix\raw_credits.csv')
netflix_raw_titles = pd.read_csv(r'E:\data analysis projects\Netflix\raw_titles.csv')

# %% [markdown]
# <a id="intro"></a>
# <h2>
#       <font color = blue >
#             <span style='font-family:Georgia'>
#             1. raw credits data set:
#             </span>
#         </font>
# </h2>

# %%
netflix_raw_credits
# Out:
#        index  person_id         id                    name  \
# 0          0       3748    tm84618          Robert De Niro
# 1          1      14658    tm84618            Jodie Foster
# 2          2       7064    tm84618           Albert Brooks
# 3          3       3739    tm84618           Harvey Keitel
# 4          4      48933    tm84618         Cybill Shepherd
# ...      ...        ...        ...                     ...
# 77208  77208    1347054  tm1098060  Nnenna Rachael Okonkwo
# 77209  77209     157590  tm1098060           Lucien Morgan
# 77210  77210     129059  tm1098060        Magdalena Korpas
# 77211  77211    2050199  tm1098060        Mistura Olusanya
# 77212  77212    2050423  tm1098060              Yemi Amodu
#
#                      character      role
# 0                Travis Bickle     ACTOR
# 1                Iris Steensma     ACTOR
# 2                          Tom     ACTOR
# 3      Matthew 'Sport' Higgins     ACTOR
# 4                        Betsy     ACTOR
# ...

# %%
netflix_raw_credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77213 entries, 0 to 77212
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      77213 non-null  int64
#  1   person_id  77213 non-null  int64
#  2   id         77213 non-null  object
#  3   name       77213 non-null  object
#  4   character  67586 non-null  object
#  5   role       77213 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 3.5+ MB

# %%
netflix_raw_credits.isna().sum(), netflix_raw_credits.isna().sum() / len(netflix_raw_credits)
# Out:
# (index           0
#  person_id       0
#  id              0
#  name            0
#  character    9627
#  role            0
#  dtype: int64,
#  index        0.000000
#  person_id    0.000000
#  id           0.000000
#  name         0.000000
#  character    0.124681
#  role         0.000000
#  dtype: float64)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <span style='font-family:Georgia'>
#         <b>Insight: </b><br>
#         nu needed data set
#     </span>
# </div>

# %% [markdown]
# <a id="intro"></a>
# <h2>
#       <font color = blue >
#             <span style='font-family:Georgia'>
#             2. raw titles data set:
#             </span>
#         </font>
# </h2>

# %%
netflix_raw_titles
# Out:
#       index         id                                title   type  \
# 0         0   ts300399  Five Came Back: The Reference Films   SHOW
# 1         1    tm84618                          Taxi Driver  MOVIE
# 2         2   tm127384      Monty Python and the Holy Grail  MOVIE
# 3         3    tm70993                        Life of Brian  MOVIE
# 4         4   tm190788                         The Exorcist  MOVIE
# ...     ...        ...                                  ...    ...
# 5801   5801  tm1014599                            Fine Wine  MOVIE
# 5802   5802  tm1108171                       Edis Starlight  MOVIE
# 5803   5803  tm1045018                                Clash  MOVIE
# 5804   5804  tm1098060                       Shadow Parties  MOVIE
# 5805   5805   ts271048   Mighty Little Bheem: Kite Festival   SHOW
#
#       release_year age_certification  runtime  \
# 0             1945             TV-MA       48
# 1             1976                 R      113
# ...

# %%
netflix_raw_titles.isna().sum() / len(netflix_raw_titles)
# Out:
# index                   0.000000
# id                      0.000000
# title                   0.000172
# type                    0.000000
# release_year            0.000000
# age_certification       0.449535
# runtime                 0.000000
# genres                  0.000000
# production_countries    0.000000
# seasons                 0.647434
# imdb_id                 0.076473
# imdb_score              0.090079
# imdb_votes              0.092835
# dtype: float64

# %% [markdown]
# <a id="intro"></a>
# <h2>
#       <font color = blue >
#             <span style='font-family:Georgia'>
#             3. Best movies:
#             </span>
#         </font>
# </h2>

# %%
netflix_bestMovies_By_Year
# Out:
#     index                                           TITLE  RELEASE_YEAR  \
# 0       0                                 White Christmas          1954
# 1       1                            The Guns of Navarone          1961
# 2       2                                    My Fair Lady          1964
# 3       3                                Bonnie and Clyde          1967
# 4       4                                     Dirty Harry          1971
# 5       5                                    The Exorcist          1973
# 6       6                 Monty Python and the Holy Grail          1975
# 7       7                                     Taxi Driver          1976
# 8       8                                   Life of Brian          1979
# 9       9                                 The Blue Lagoon          1980
# 10     10                                           Annie          1982
# 11     11                                       Christine          1983
# ...

# %%
netflix_bestMovies
# Out:
#      index                                     TITLE  RELEASE_YEAR  SCORE  \
# 0        0  David Attenborough: A Life on Our Planet          2020    9.0
# 1        1                                 Inception          2010    8.8
# 2        2                              Forrest Gump          1994    8.8
# 3        3                                Anbe Sivam          2003    8.7
# 4        4                        Bo Burnham: Inside          2021    8.7
# ..     ...                                       ...           ...    ...
# 382    382                                  The Trip          2021    6.9
# 383    383                                  The Dirt          2019    6.9
# 384    384                                   Top Gun          1986    6.9
# 385    385                               Radhe Shyam          2022    6.9
# 386    386                       Sorry to Bother You          2018    6.9
#
#      NUMBER_OF_VOTES  DURATION   MAIN_GENRE MAIN_PRODUCTION
# ...

# %%
netflix_bestMovies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387 entries, 0 to 386
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            387 non-null    int64
#  1   TITLE            387 non-null    object
#  2   RELEASE_YEAR     387 non-null    int64
#  3   SCORE            387 non-null    float64
#  4   NUMBER_OF_VOTES  387 non-null    int64
#  5   DURATION         387 non-null    int64
#  6   MAIN_GENRE       387 non-null    object
#  7   MAIN_PRODUCTION  387 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 24.3+ KB

# %%
netflix_bestMovies.isna().sum() / len(netflix_bestMovies)
# Out:
# index              0.0
# TITLE              0.0
# RELEASE_YEAR       0.0
# SCORE              0.0
# NUMBER_OF_VOTES    0.0
# DURATION           0.0
# MAIN_GENRE         0.0
# MAIN_PRODUCTION    0.0
# dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <span style='font-family:Georgia'>
#         <b>Insight: </b><br>
#         the movies data set don't need any cleaning, just need to identify the categorizations for the columns, to use them in visualization
#     </span>
# </div>

# %% [markdown]
# <a id="intro"></a>
# <h2>
#       <font color = blue >
#             <span style='font-family:Georgia'>
#             3. Best Shows:
#             </span>
#         </font>
# </h2>

# %%
netflix_bestShow_By_Year
# Out:
#     index                         TITLE  RELEASE_YEAR  SCORE  \
# 0       0  Monty Python's Flying Circus          1969    8.8
# 1       1                  Knight Rider          1982    6.9
# 2       2                      Seinfeld          1989    8.9
# 3       3    Star Trek: Deep Space Nine          1993    8.1
# 4       4       Neon Genesis Evangelion          1995    8.5
# 5       5                 Stargate SG-1          1997    8.4
# 6       6                  Cowboy Bebop          1998    8.9
# 7       7                     One Piece          1999    8.8
# 8       8                 Gilmore Girls          2000    8.2
# 9       9             Trailer Park Boys          2001    8.6
# 10     10                        Naruto          2002    8.4
# 11     11              Chappelle's Show          2003    8.8
# 12     12                      The 4400          2004    7.3
# 13     13    Avatar: The Last Airbender          2005    9.3
# ...

# %%
netflix_bestShows
# Out:
#      index                       TITLE  RELEASE_YEAR  SCORE  NUMBER_OF_VOTES  \
# 0        0                Breaking Bad          2008    9.5          1727694
# 1        1  Avatar: The Last Airbender          2005    9.3           297336
# 2        2                  Our Planet          2019    9.3            41386
# 3        3                Kota Factory          2019    9.3            66985
# 4        4              The Last Dance          2020    9.1           108321
# ..     ...                         ...           ...    ...              ...
# 241    241                 Evil Genius          2018    7.5            27516
# 242    242              13 Reasons Why          2017    7.5           282373
# 243    243                       Lupin          2021    7.5           100575
# 244    244          All of Us Are Dead          2022    7.5            41393
# 245    245     I Am Not Okay with This          2020    7.5            56459
#
# ...

# %%
netflix_bestShows.isna().sum() / len(netflix_bestShows)
# Out:
# index                0.0
# TITLE                0.0
# RELEASE_YEAR         0.0
# SCORE                0.0
# NUMBER_OF_VOTES      0.0
# DURATION             0.0
# NUMBER_OF_SEASONS    0.0
# MAIN_GENRE           0.0
# MAIN_PRODUCTION      0.0
# dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <span style='font-family:Georgia'>
#         <b>Insight: </b><br>
#         the Shows data set don't need any cleaning, just need to identify the categorizations for the columns, to use them in visualization
#     </span>
# </div>
