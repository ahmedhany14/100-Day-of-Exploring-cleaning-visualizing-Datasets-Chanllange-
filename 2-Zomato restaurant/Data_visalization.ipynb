# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
pd.options.display.max_columns = None
zomato_df = pd.read_csv(r'E:\data analysis projects\Zomato Data Set Analysis & Visualization\cleaned_zomato.csv')

# %%
zomato_df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table      rate  votes    location       resturant_type  \
# ...

# %% [markdown]
# # online_order or not

# %%
plt.figure(figsize=(5,5))

sns.countplot(
    data=zomato_df,
    x='online_order',
    width=.2,
    palette = 'inferno'
)
plt.title("Restaurants delivering Online or not")
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <span style='font-family:Georgia'>
#         <b>Insight: </b><br>
#         number of resturants that has online more than  resturants that hasn't online
#     </span>
# </div>

# %%
plt.figure(figsize=(5,5))
sns.displot(
    data=zomato_df,
    x='online_order',
    y='rate',
    rug=True,
    palette = 'inferno'
)
plt.title("Restaurants delivering Online or not VS rating")
plt.legend()
# Out:
# C:\Users\ahmed hany\AppData\Local\Temp\ipykernel_2708\1982515079.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(
# d:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Restaurants allowing table booking or not

# %%
table_count = zomato_df["book_table"].value_counts()

plt.pie(table_count.values, labels=table_count.index, autopct="%1.0f%%")
plt.title("Restaurants allowing table booking or not")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(5,5))

sns.barplot(
    data=zomato_df,
    x='book_table',
    y='rate',
    width=.2,
)
plt.title("Restaurants allowing table booking or not VS rate")
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <span style='font-family:Georgia'>
#         <b>Insight: </b><br>
#         resturants that has table booking has the higher rate
#     </span>
# </div>

# %% [markdown]
# # Best locations

# %%
Locations_cities = pd.DataFrame(zomato_df.groupby('location')['rate'].mean())
Locations_cities['location_count'] = zomato_df['location'].value_counts()
top20 = Locations_cities.sort_values(by='rate' ,ascending=False).head(20)
top20
# Out:
#                            rate  location_count
# location
# Koramangala 5th Block  3.982478            2504
# Koramangala 4th Block  3.878354            1017
# Koramangala 7th Block  3.835902            1181
# Indiranagar            3.812834            2083
# Koramangala 6th Block  3.770889            1156
# Jayanagar              3.766941            1926
# Ulsoor                 3.750157            1023
# Brigade Road           3.702988            1218
# others                 3.697280           19239
# Koramangala 1st Block  3.692447            1238
# Sarjapur Road          3.685043            1065
# JP Nagar               3.677370            2235
# HSR                    3.672169            2523
# Whitefield             3.636393            2144
# BTM                    3.598464            5145
# Marathahalli           3.571135            1846
# Bellandur              3.557482            1286
# Electronic City        3.553381            1258
# ...

# %% [markdown]
# # Types of Services

# %%
zomato_df['type'].value_counts()
# Out:
# type
# Delivery              25942
# Dine-out              17779
# Desserts               3593
# Cafes                  1723
# Drinks & nightlife     1101
# Buffet                  882
# Pubs and bars           697
# Name: count, dtype: int64

# %%
sns.countplot(
    data=zomato_df,
    y='type'
)
# Out:
# <Axes: xlabel='count', ylabel='type'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(
    data=zomato_df,
    x='type',
    y='rate',
    hue='book_table',
    width=.5,
    saturation=.5
)
# Out:
# <Axes: xlabel='type', ylabel='rate'>
